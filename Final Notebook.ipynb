# %%
# !python ner_training.py \
    --data-dir /kaggle/input/datasets/ikramahelahi/internship2 \
    --model bert-base-cased \
    --epochs 3 \
    --batch-size 8 \
    --test-file test_with_emails.json
# Out:
# Labels: ['O', 'B-PER', 'I-PER', 'B-EMAIL']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100%|█████████████████████████████| 570/570 [00:00<00:00, 16.0kB/s]
# tokenizer_config.json: 100%|██████████████████| 49.0/49.0 [00:00<00:00, 232kB/s]
# vocab.txt: 213kB [00:00, 8.03MB/s]
# tokenizer.json: 436kB [00:00, 4.18MB/s]
#
# Preparing tokenized encodings (this may take a moment)...
# Using device: cuda
# model.safetensors: 100%|██████████████████████| 436M/436M [00:03<00:00, 140MB/s]
# Loading weights: 100%|█| 197/197 [00:00<00:00, 1706.70it/s, Materializing param=
# BertForTokenClassification LOAD REPORT from: bert-base-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# bert.pooler.dense.bias                     | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# bert.pooler.dense.weight                   | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#
# Starting training...
# Epoch 1 | Step 20 | Avg loss 0.4362
# Epoch 1 | Step 40 | Avg loss 0.2732
# Epoch 1 | Step 60 | Avg loss 0.1958
# Epoch 1 | Step 80 | Avg loss 0.1533
# Epoch 1 | Step 100 | Avg loss 0.1293
# Epoch 1 | Step 120 | Avg loss 0.1131
# Epoch 1 | Step 140 | Avg loss 0.0997
# Epoch 1 | Step 160 | Avg loss 0.0895
# Epoch 1 | Step 180 | Avg loss 0.0815
# Epoch 1 | Step 200 | Avg loss 0.0762
# Epoch 1 | Step 220 | Avg loss 0.0714
# Epoch 1 | Step 240 | Avg loss 0.0671
# Epoch 1 | Step 260 | Avg loss 0.0631
# Epoch 1 | Step 280 | Avg loss 0.0591
# Epoch 1 | Step 300 | Avg loss 0.0568
# Epoch 1 | Step 320 | Avg loss 0.0547
# Epoch 1 | Step 340 | Avg loss 0.0523
# Epoch 1 | Step 360 | Avg loss 0.0506
# Epoch 1 | Step 380 | Avg loss 0.0488
# Epoch 1 | Step 400 | Avg loss 0.0472
# Epoch 1 | Step 420 | Avg loss 0.0461
# Epoch 1 | Step 440 | Avg loss 0.0448
# Epoch 1 | Step 460 | Avg loss 0.0437
# Epoch 1 | Step 480 | Avg loss 0.0424
# Epoch 1 | Step 500 | Avg loss 0.0410
# Epoch 1 | Step 520 | Avg loss 0.0401
# Epoch 1 | Step 540 | Avg loss 0.0390
# Epoch 1 | Step 560 | Avg loss 0.0380
# Epoch 1 | Step 2780 | Avg loss 0.0182
# Epoch 1 | Step 2800 | Avg loss 0.0181
# Epoch 1 | Step 2820 | Avg loss 0.0181
# Epoch 1 | Step 2840 | Avg loss 0.0180
# Epoch 1 completed. Avg training loss: 0.0180
#
# Evaluating on validation set...
# Validation loss: 0.0107 | Precision: 0.9761 | Recall: 0.9726 | F1: 0.9744 | Accuracy: 0.9970
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#        EMAIL       1.00      1.00      1.00       865
#          PER       0.97      0.97      0.97      8090
#
#    micro avg       0.98      0.97      0.97      8955
#    macro avg       0.99      0.98      0.99      8955
# weighted avg       0.98      0.97      0.97      8955
#
#
# Epoch metrics table so far:
# Epoch | Training Loss | Validation Loss | Per Precision | Per Recall | Per F1   | Per Fpr  | Per Fnr  | Email Precision | Email Recall | Email F1 | Email Fpr | Email Fnr | Overall Precision | Overall Recall | Overall F1 | Accuracy
# ------+---------------+-----------------+---------------+------------+----------+----------+----------+-----------------+--------------+----------+-----------+-----------+-------------------+----------------+------------+---------
# 1     | 0.017997      | 0.01074         | 0.985179      | 0.984263   | 0.984721 | 0.001616 | 0.015737 | 0.998845        | 1.0          | 0.999422 | 7e-06     | 0.0       | 0.985977          | 0.98518        | 0.985579   | 0.996987
# Epoch 2 | Step 20 | Avg loss 0.0124
# Epoch 2 | Step 40 | Avg loss 0.0099
# Epoch 2 | Step 60 | Avg loss 0.0083
# Epoch 2 | Step 80 | Avg loss 0.0084
# Epoch 2 | Step 100 | Avg loss 0.0084
# Epoch 2 | Step 120 | Avg loss 0.0082
# Epoch 2 | Step 140 | Avg loss 0.0081
# Epoch 2 | Step 160 | Avg loss 0.0081
# Epoch 2 | Step 180 | Avg loss 0.0085
# Epoch 2 | Step 200 | Avg loss 0.0082
# Epoch 2 | Step 220 | Avg loss 0.0080
# Epoch 2 | Step 240 | Avg loss 0.0080
# Epoch 2 | Step 260 | Avg loss 0.0079
# Epoch 2 | Step 280 | Avg loss 0.0076
# Epoch 2 | Step 300 | Avg loss 0.0074
# Epoch 2 | Step 320 | Avg loss 0.0077
# Epoch 2 | Step 340 | Avg loss 0.0077
# Epoch 2 | Step 360 | Avg loss 0.0076
# Epoch 2 | Step 380 | Avg loss 0.0074
# Epoch 2 | Step 400 | Avg loss 0.0076
# Epoch 2 | Step 420 | Avg loss 0.0075
# Epoch 2 | Step 440 | Avg loss 0.0074
# Epoch 2 | Step 460 | Avg loss 0.0074
# Epoch 2 | Step 480 | Avg loss 0.0076
# Epoch 2 | Step 500 | Avg loss 0.0076
# Epoch 2 | Step 520 | Avg loss 0.0074
# Epoch 2 | Step 540 | Avg loss 0.0075
# Epoch 2 | Step 560 | Avg loss 0.0074
# Epoch 2 | Step 580 | Avg loss 0.0074
# Epoch 2 | Step 600 | Avg loss 0.0073
# Epoch 2 | Step 620 | Avg loss 0.0074
# Epoch 2 | Step 640 | Avg loss 0.0072
# Epoch 2 | Step 1760 | Avg loss 0.0076
# Epoch 2 | Step 1780 | Avg loss 0.0076
# Epoch 2 | Step 1800 | Avg loss 0.0076
# Epoch 2 | Step 1820 | Avg loss 0.0076
# Epoch 2 | Step 1840 | Avg loss 0.0076
# Epoch 2 | Step 1860 | Avg loss 0.0076
# Epoch 2 | Step 1880 | Avg loss 0.0076
# Epoch 2 | Step 1900 | Avg loss 0.0076
# Epoch 2 | Step 1920 | Avg loss 0.0076
# Epoch 2 | Step 1940 | Avg loss 0.0076
# Epoch 2 | Step 1960 | Avg loss 0.0076
# Epoch 2 | Step 1980 | Avg loss 0.0075
# Epoch 2 | Step 2000 | Avg loss 0.0076
# Epoch 2 | Step 2020 | Avg loss 0.0076
# Epoch 2 | Step 2040 | Avg loss 0.0075
# Epoch 2 | Step 2060 | Avg loss 0.0075
# Epoch 2 | Step 2080 | Avg loss 0.0075
# Epoch 2 | Step 2100 | Avg loss 0.0074
# Epoch 2 | Step 2120 | Avg loss 0.0074
# Epoch 2 | Step 2140 | Avg loss 0.0075
# Epoch 2 | Step 2160 | Avg loss 0.0075
# Epoch 2 | Step 2180 | Avg loss 0.0075
# Epoch 2 | Step 2200 | Avg loss 0.0075
# Epoch 2 | Step 2220 | Avg loss 0.0075
# Epoch 2 | Step 2240 | Avg loss 0.0075
# Epoch 2 | Step 2260 | Avg loss 0.0075
# Epoch 2 | Step 2280 | Avg loss 0.0074
# Epoch 2 | Step 2300 | Avg loss 0.0074
# Epoch 2 | Step 2320 | Avg loss 0.0074
# Epoch 2 | Step 2340 | Avg loss 0.0074
# Epoch 2 | Step 2360 | Avg loss 0.0074
# Epoch 2 | Step 2380 | Avg loss 0.0074
# Epoch 2 | Step 2400 | Avg loss 0.0075
# Epoch 2 | Step 2420 | Avg loss 0.0075
# Epoch 2 | Step 2440 | Avg loss 0.0075
# Epoch 2 | Step 2460 | Avg loss 0.0075
# Epoch 2 | Step 2480 | Avg loss 0.0076
# Epoch 2 | Step 2500 | Avg loss 0.0075
# Epoch 2 | Step 2520 | Avg loss 0.0075
# Epoch 2 | Step 2540 | Avg loss 0.0076
# Epoch 2 | Step 2560 | Avg loss 0.0076
# Epoch 2 | Step 2580 | Avg loss 0.0076
# Epoch 2 | Step 2600 | Avg loss 0.0076
# Epoch 2 | Step 2620 | Avg loss 0.0076
# Epoch 2 | Step 2640 | Avg loss 0.0077
# Epoch 2 | Step 2660 | Avg loss 0.0077
# Epoch 2 | Step 2680 | Avg loss 0.0077
# Epoch 2 | Step 2700 | Avg loss 0.0077
# Epoch 2 | Step 2720 | Avg loss 0.0077
# Epoch 2 | Step 2740 | Avg loss 0.0077
# Epoch 2 | Step 2760 | Avg loss 0.0077
# Epoch 2 | Step 2780 | Avg loss 0.0077
# Epoch 2 | Step 2800 | Avg loss 0.0077
# Epoch 2 | Step 2820 | Avg loss 0.0077
# Epoch 2 | Step 2840 | Avg loss 0.0077
# Epoch 2 completed. Avg training loss: 0.0077
#
# Evaluating on validation set...
# Validation loss: 0.0128 | Precision: 0.9644 | Recall: 0.9801 | F1: 0.9722 | Accuracy: 0.9967
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#        EMAIL       0.93      1.00      0.96       865
#          PER       0.97      0.98      0.97      8090
#
#    micro avg       0.96      0.98      0.97      8955
#    macro avg       0.95      0.99      0.97      8955
# weighted avg       0.96      0.98      0.97      8955
#
#
# Epoch metrics table so far:
# Epoch | Training Loss | Validation Loss | Per Precision | Per Recall | Per F1   | Per Fpr  | Per Fnr  | Email Precision | Email Recall | Email F1 | Email Fpr | Email Fnr | Overall Precision | Overall Recall | Overall F1 | Accuracy
# ------+---------------+-----------------+---------------+------------+----------+----------+----------+-----------------+--------------+----------+-----------+-----------+-------------------+----------------+------------+---------
# 1     | 0.017997      | 0.01074         | 0.985179      | 0.984263   | 0.984721 | 0.001616 | 0.015737 | 0.998845        | 1.0          | 0.999422 | 7e-06     | 0.0       | 0.985977          | 0.98518        | 0.985579   | 0.996987
# 2     | 0.007659      | 0.012799        | 0.981467      | 0.988698   | 0.985069 | 0.002038 | 0.011302 | 0.929108        | 1.0          | 0.963252 | 0.000467  | 0.0       | 0.978687          | 0.989828       | 0.984226   | 0.996684
# Epoch 3 | Step 20 | Avg loss 0.0055
# Epoch 3 | Step 40 | Avg loss 0.0060
# Epoch 3 | Step 60 | Avg loss 0.0051
# Epoch 3 | Step 80 | Avg loss 0.0043
# Epoch 3 | Step 100 | Avg loss 0.0043
# Epoch 3 | Step 120 | Avg loss 0.0041
# Epoch 3 | Step 140 | Avg loss 0.0044
# Epoch 3 | Step 160 | Avg loss 0.0044
# Epoch 3 | Step 180 | Avg loss 0.0045
# Epoch 3 | Step 200 | Avg loss 0.0047
# Epoch 3 | Step 220 | Avg loss 0.0047
# Epoch 3 | Step 240 | Avg loss 0.0046
# Epoch 3 | Step 260 | Avg loss 0.0044
# Epoch 3 | Step 280 | Avg loss 0.0047
# Epoch 3 | Step 300 | Avg loss 0.0045
# Epoch 3 | Step 320 | Avg loss 0.0044
# Epoch 3 | Step 340 | Avg loss 0.0047
# Epoch 3 | Step 360 | Avg loss 0.0047
# Epoch 3 | Step 380 | Avg loss 0.0046
# Epoch 3 | Step 400 | Avg loss 0.0047
# Epoch 3 | Step 420 | Avg loss 0.0047
# Epoch 3 | Step 440 | Avg loss 0.0046
# Epoch 3 | Step 460 | Avg loss 0.0046
# Epoch 3 | Step 480 | Avg loss 0.0045
# Epoch 3 | Step 500 | Avg loss 0.0045
# Epoch 3 | Step 520 | Avg loss 0.0045
# Epoch 3 | Step 540 | Avg loss 0.0046
# Epoch 3 | Step 560 | Avg loss 0.0048
# Epoch 3 | Step 580 | Avg loss 0.0048
# Epoch 3 | Step 600 | Avg loss 0.0048
# Epoch 3 | Step 620 | Avg loss 0.0047
# Epoch 3 | Step 640 | Avg loss 0.0047
# Epoch 3 | Step 660 | Avg loss 0.0048
# Epoch 3 | Step 680 | Avg loss 0.0047
# Epoch 3 | Step 700 | Avg loss 0.0047
# Epoch 3 | Step 720 | Avg loss 0.0048
# Epoch 3 | Step 740 | Avg loss 0.0049
# Epoch 3 | Step 760 | Avg loss 0.0050
# Epoch 3 | Step 780 | Avg loss 0.0050
# Epoch 3 | Step 800 | Avg loss 0.0051
# Epoch 3 | Step 820 | Avg loss 0.0052
# Epoch 3 | Step 840 | Avg loss 0.0052
# Epoch 3 | Step 860 | Avg loss 0.0052
# Epoch 3 | Step 880 | Avg loss 0.0051
# Epoch 3 | Step 900 | Avg loss 0.0051
# Epoch 3 | Step 920 | Avg loss 0.0051
# Epoch 3 | Step 940 | Avg loss 0.0050
# Epoch 3 | Step 960 | Avg loss 0.0050
# Epoch 3 | Step 980 | Avg loss 0.0049
# Epoch 3 | Step 1000 | Avg loss 0.0049
# Epoch 3 | Step 1020 | Avg loss 0.0048
# Epoch 3 | Step 1040 | Avg loss 0.0049
# Epoch 3 | Step 1060 | Avg loss 0.0049
# Epoch 3 | Step 1080 | Avg loss 0.0048
# Epoch 3 | Step 1100 | Avg loss 0.0048
# Epoch 3 | Step 1120 | Avg loss 0.0047
# Epoch 3 | Step 1140 | Avg loss 0.0048
# Epoch 3 | Step 1160 | Avg loss 0.0048
# Epoch 3 | Step 1180 | Avg loss 0.0048
# Epoch 3 | Step 1200 | Avg loss 0.0048
# Epoch 3 | Step 1220 | Avg loss 0.0048
# Epoch 3 | Step 1240 | Avg loss 0.0047
# Epoch 3 | Step 1260 | Avg loss 0.0048
# Epoch 3 | Step 1280 | Avg loss 0.0048
# Epoch 3 | Step 1300 | Avg loss 0.0048
# Epoch 3 | Step 1320 | Avg loss 0.0048
# Epoch 3 | Step 1340 | Avg loss 0.0048
# Epoch 3 | Step 1360 | Avg loss 0.0047
# Epoch 3 | Step 1380 | Avg loss 0.0047
# Epoch 3 | Step 1400 | Avg loss 0.0048
# Epoch 3 | Step 1420 | Avg loss 0.0048
# Epoch 3 | Step 1440 | Avg loss 0.0048
# Epoch 3 | Step 1460 | Avg loss 0.0048
# Epoch 3 | Step 1480 | Avg loss 0.0047
# Epoch 3 | Step 1500 | Avg loss 0.0048
# Epoch 3 | Step 1520 | Avg loss 0.0048
# Epoch 3 | Step 1540 | Avg loss 0.0048
# Epoch 3 | Step 1560 | Avg loss 0.0049
# Epoch 3 | Step 1580 | Avg loss 0.0049
# Epoch 3 | Step 1600 | Avg loss 0.0050
# Epoch 3 | Step 1620 | Avg loss 0.0050
# Epoch 3 | Step 1640 | Avg loss 0.0050
# Epoch 3 | Step 1660 | Avg loss 0.0049
# Epoch 3 | Step 1680 | Avg loss 0.0049
# Epoch 3 | Step 1700 | Avg loss 0.0050
# Epoch 3 | Step 1720 | Avg loss 0.0050
# Epoch 3 | Step 1740 | Avg loss 0.0049
# Epoch 3 | Step 1760 | Avg loss 0.0049
# Epoch 3 | Step 1780 | Avg loss 0.0049
# Epoch 3 | Step 1800 | Avg loss 0.0049
# Epoch 3 | Step 1820 | Avg loss 0.0049
# Epoch 3 | Step 1840 | Avg loss 0.0048
# Epoch 3 | Step 1860 | Avg loss 0.0049
# Epoch 3 | Step 1880 | Avg loss 0.0050
# Epoch 3 | Step 1900 | Avg loss 0.0050
# Epoch 3 | Step 1920 | Avg loss 0.0050
# Epoch 3 | Step 1940 | Avg loss 0.0050
# Epoch 3 | Step 1960 | Avg loss 0.0050
# Epoch 3 | Step 1980 | Avg loss 0.0050
# Epoch 3 | Step 2000 | Avg loss 0.0050
# Epoch 3 | Step 2020 | Avg loss 0.0050
# Epoch 3 | Step 2040 | Avg loss 0.0050
# Epoch 3 | Step 2060 | Avg loss 0.0050
# Epoch 3 | Step 2080 | Avg loss 0.0049
# Epoch 3 | Step 2100 | Avg loss 0.0050
# Epoch 3 | Step 2120 | Avg loss 0.0050
# Epoch 3 | Step 2140 | Avg loss 0.0050
# Epoch 3 | Step 2160 | Avg loss 0.0050
# Epoch 3 | Step 2180 | Avg loss 0.0050
# Epoch 3 | Step 2200 | Avg loss 0.0050
# Epoch 3 | Step 2220 | Avg loss 0.0051
# Epoch 3 | Step 2240 | Avg loss 0.0052
# Epoch 3 | Step 2260 | Avg loss 0.0052
# Epoch 3 | Step 2280 | Avg loss 0.0052
# Epoch 3 | Step 2300 | Avg loss 0.0052
# Epoch 3 | Step 2320 | Avg loss 0.0053
# Epoch 3 | Step 2340 | Avg loss 0.0052
# Epoch 3 | Step 2360 | Avg loss 0.0052
# Epoch 3 | Step 2380 | Avg loss 0.0052
# Epoch 3 | Step 2400 | Avg loss 0.0052
# Epoch 3 | Step 2420 | Avg loss 0.0052
# Epoch 3 | Step 2440 | Avg loss 0.0052
# Epoch 3 | Step 2460 | Avg loss 0.0052
# Epoch 3 | Step 2480 | Avg loss 0.0052
# Epoch 3 | Step 2500 | Avg loss 0.0052
# Epoch 3 | Step 2520 | Avg loss 0.0052
# Epoch 3 | Step 2540 | Avg loss 0.0052
# Epoch 3 | Step 2560 | Avg loss 0.0052
# Epoch 3 | Step 2580 | Avg loss 0.0052
# Epoch 3 | Step 2600 | Avg loss 0.0051
# Epoch 3 | Step 2620 | Avg loss 0.0051
# Epoch 3 | Step 2640 | Avg loss 0.0051
# Epoch 3 | Step 2660 | Avg loss 0.0051
# Epoch 3 | Step 2680 | Avg loss 0.0051
# Epoch 3 | Step 2700 | Avg loss 0.0051
# Epoch 3 | Step 2720 | Avg loss 0.0051
# Epoch 3 | Step 2740 | Avg loss 0.0051
# Epoch 3 | Step 2760 | Avg loss 0.0051
# Epoch 3 | Step 2780 | Avg loss 0.0050
# Epoch 3 | Step 2800 | Avg loss 0.0050
# Epoch 3 | Step 2820 | Avg loss 0.0051
# Epoch 3 | Step 2840 | Avg loss 0.0051
# Epoch 3 completed. Avg training loss: 0.0051
#
# Evaluating on validation set...
# Validation loss: 0.0122 | Precision: 0.9748 | Recall: 0.9734 | F1: 0.9741 | Accuracy: 0.9969
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#        EMAIL       0.99      1.00      1.00       865
#          PER       0.97      0.97      0.97      8090
#
#    micro avg       0.97      0.97      0.97      8955
#    macro avg       0.98      0.99      0.98      8955
# weighted avg       0.97      0.97      0.97      8955
#
#
# Epoch metrics table so far:
# Epoch | Training Loss | Validation Loss | Per Precision | Per Recall | Per F1   | Per Fpr  | Per Fnr  | Email Precision | Email Recall | Email F1 | Email Fpr | Email Fnr | Overall Precision | Overall Recall | Overall F1 | Accuracy
# ------+---------------+-----------------+---------------+------------+----------+----------+----------+-----------------+--------------+----------+-----------+-----------+-------------------+----------------+------------+---------
# 1     | 0.017997      | 0.01074         | 0.985179      | 0.984263   | 0.984721 | 0.001616 | 0.015737 | 0.998845        | 1.0          | 0.999422 | 7e-06     | 0.0       | 0.985977          | 0.98518        | 0.985579   | 0.996987
# 2     | 0.007659      | 0.012799        | 0.981467      | 0.988698   | 0.985069 | 0.002038 | 0.011302 | 0.929108        | 1.0          | 0.963252 | 0.000467  | 0.0       | 0.978687          | 0.989828       | 0.984226   | 0.996684
# 3     | 0.005104      | 0.012231        | 0.986363      | 0.983047   | 0.984702 | 0.001484 | 0.016953 | 0.991972        | 1.0          | 0.99597  | 5e-05     | 0.0       | 0.986694          | 0.984035       | 0.985363   | 0.996945
# Writing model shards: 100%|███████████████████████| 1/1 [00:00<00:00,  1.30it/s]
#
# Saved model to models/bert-base-cased_finetuned_small
#
# Epoch-wise metrics table:
# Epoch | Training Loss | Validation Loss | Per Precision | Per Recall | Per F1   | Per Fpr  | Per Fnr  | Email Precision | Email Recall | Email F1 | Email Fpr | Email Fnr | Overall Precision | Overall Recall | Overall F1 | Accuracy
# ------+---------------+-----------------+---------------+------------+----------+----------+----------+-----------------+--------------+----------+-----------+-----------+-------------------+----------------+------------+---------
# 1     | 0.017997      | 0.01074         | 0.985179      | 0.984263   | 0.984721 | 0.001616 | 0.015737 | 0.998845        | 1.0          | 0.999422 | 7e-06     | 0.0       | 0.985977          | 0.98518        | 0.985579   | 0.996987
# 2     | 0.007659      | 0.012799        | 0.981467      | 0.988698   | 0.985069 | 0.002038 | 0.011302 | 0.929108        | 1.0          | 0.963252 | 0.000467  | 0.0       | 0.978687          | 0.989828       | 0.984226   | 0.996684
# 3     | 0.005104      | 0.012231        | 0.986363      | 0.983047   | 0.984702 | 0.001484 | 0.016953 | 0.991972        | 1.0          | 0.99597  | 5e-05     | 0.0       | 0.986694          | 0.984035       | 0.985363   | 0.996945
# Saved metrics CSV to training_metrics.csv
#
# Evaluating on test set...
# Test loss: 0.0125 | Precision: 0.9782 | Recall: 0.9728 | F1: 0.9755 | Accuracy: 0.9969
#
# Test per-entity metrics (PER, EMAIL, PII):
# Entity | Support | accuracy | precision | recall | f1 | fpr | fnr
# PER | 9166 | 0.996905 | 0.988468 | 0.981890 | 0.985168 | 0.001340 | 0.018110
# EMAIL | 534 | 0.999989 | 0.998131 | 1.000000 | 0.999065 | 0.000011 | 0.000000
# PII | 9700 | 0.996893 | 0.989004 | 0.982887 | 0.985936 | 0.001362 | 0.017113
# Saved test metrics CSV to test_metrics.csv

# %%
import pandas as pd

# Epoch-wise metrics
epoch_data = [
    [1, 0.017997, 0.01074, 0.985179, 0.984263, 0.984721, 0.001616, 0.015737, 0.998845, 1.0, 0.999422, 0.000007, 0.0, 0.985977, 0.98518, 0.985579, 0.996987],
    [2, 0.007659, 0.012799, 0.981467, 0.988698, 0.985069, 0.002038, 0.011302, 0.929108, 1.0, 0.963252, 0.000467, 0.0, 0.978687, 0.989828, 0.984226, 0.996684],
    [3, 0.005104, 0.012231, 0.986363, 0.983047, 0.984702, 0.001484, 0.016953, 0.991972, 1.0, 0.995970, 0.000050, 0.0, 0.986694, 0.984035, 0.985363, 0.996945]
]

epoch_columns = [
    "Epoch", "Training Loss", "Validation Loss", "Per Precision", "Per Recall", "Per F1",
    "Per FPR", "Per FNR", "Email Precision", "Email Recall", "Email F1",
    "Email FPR", "Email FNR", "Overall Precision", "Overall Recall", "Overall F1", "Accuracy"
]

df_epochs = pd.DataFrame(epoch_data, columns=epoch_columns)

# Test summary
test_summary = {
    "Loss": 0.0125,
    "Precision": 0.9782,
    "Recall": 0.9728,
    "F1": 0.9755,
    "Accuracy": 0.9969
}

df_test_summary = pd.DataFrame([test_summary])

# Per-entity metrics
entity_data = [
    ["PER", 9166, 0.996905, 0.988468, 0.981890, 0.985168, 0.001340, 0.018110],
    ["EMAIL", 534, 0.999989, 0.998131, 1.000000, 0.999065, 0.000011, 0.000000],
    ["PII", 9700, 0.996893, 0.989004, 0.982887, 0.985936, 0.001362, 0.017113]
]

entity_columns = ["Entity", "Support", "Accuracy", "Precision", "Recall", "F1", "FPR", "FNR"]

df_entities = pd.DataFrame(entity_data, columns=entity_columns)

# Display tables
print("Epoch-wise Metrics:")
display(df_epochs)

print("\nTest Summary:")
display(df_test_summary)

print("\nPer-Entity Metrics:")
display(df_entities)

# Optional: save to CSV
df_epochs.to_csv("epoch_metrics.csv", index=False)
df_test_summary.to_csv("test_summary.csv", index=False)
df_entities.to_csv("entity_metrics.csv", index=False)
# Out:
# Epoch-wise Metrics:
#    Epoch  Training Loss  Validation Loss  Per Precision  Per Recall    Per F1  \
# 0      1       0.017997         0.010740       0.985179    0.984263  0.984721
# 1      2       0.007659         0.012799       0.981467    0.988698  0.985069
# 2      3       0.005104         0.012231       0.986363    0.983047  0.984702
#
#     Per FPR   Per FNR  Email Precision  Email Recall  Email F1  Email FPR  \
# 0  0.001616  0.015737         0.998845           1.0  0.999422   0.000007
# 1  0.002038  0.011302         0.929108           1.0  0.963252   0.000467
# 2  0.001484  0.016953         0.991972           1.0  0.995970   0.000050
#
#    Email FNR  Overall Precision  Overall Recall  Overall F1  Accuracy
# 0        0.0           0.985977        0.985180    0.985579  0.996987
# 1        0.0           0.978687        0.989828    0.984226  0.996684
# 2        0.0           0.986694        0.984035    0.985363  0.996945
# Test Summary:
#      Loss  Precision  Recall      F1  Accuracy
# 0  0.0125     0.9782  0.9728  0.9755    0.9969
# Per-Entity Metrics:
#   Entity  Support  Accuracy  Precision    Recall        F1       FPR       FNR
# 0    PER     9166  0.996905   0.988468  0.981890  0.985168  0.001340  0.018110
# 1  EMAIL      534  0.999989   0.998131  1.000000  0.999065  0.000011  0.000000
# 2    PII     9700  0.996893   0.989004  0.982887  0.985936  0.001362  0.017113

# %%
import os

# 1. Ensure the directory exists
os.makedirs('processed_data', exist_ok=True)

# 2. Create the link with the EXACT name the script is looking for
# !ln -sf /kaggle/input/datasets/ikramahelahi/internship2/test_with_emails.json processed_data/test_with_emails.json

# 3. Verify the link exists
# !ls -l processed_data/test_with_emails.json

# 4. Run the script
# !python phase3_llm_masking.py --model llama3.2:1b
# Out:
# lrwxrwxrwx 1 root root 69 May  4 11:33 processed_data/test_with_emails.json -> /kaggle/input/datasets/ikramahelahi/internship2/test_with_emails.json
# Phase3: LLM masking — samples: 200 mode: transformers
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|█| 190/190 [00:00<00:00, 1672.09it/s, Materializing param=
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
#
# Entity | Support | tp  | fp  | fn  | tn   | accuracy | precision | recall   | f1       | fpr      | fnr
# -------+---------+-----+-----+-----+------+----------+-----------+----------+----------+----------+---------
# PER    | 461     | 300 | 121 | 161 | 4203 | 0.941066 | 0.712589  | 0.650759 | 0.680272 | 0.027983 | 0.349241
# EMAIL  | 29      | 10  | 0   | 19  | 4756 | 0.996029 | 1.0       | 0.344828 | 0.512821 | 0.0      | 0.655172
# Saved: phase3_results.json

# %%
import pandas as pd

# Entity metrics data
data = [
    ["PER", 461, 300, 121, 161, 4203, 0.941066, 0.712589, 0.650759, 0.680272, 0.027983, 0.349241],
    ["EMAIL", 29, 10, 0, 19, 4756, 0.996029, 1.0, 0.344828, 0.512821, 0.0, 0.655172]
]

columns = [
    "Entity", "Support", "TP", "FP", "FN", "TN",
    "Accuracy", "Precision", "Recall", "F1", "FPR", "FNR"
]

df = pd.DataFrame(data, columns=columns)

# Display nicely in Kaggle
display(df)

# Optional: save to CSV
df.to_csv("entity_confusion_metrics.csv", index=False)
# Out:
#   Entity  Support   TP   FP   FN    TN  Accuracy  Precision    Recall  \
# 0    PER      461  300  121  161  4203  0.941066   0.712589  0.650759
# 1  EMAIL       29   10    0   19  4756  0.996029   1.000000  0.344828
#
#          F1       FPR       FNR
# 0  0.680272  0.027983  0.349241
# 1  0.512821  0.000000  0.655172
